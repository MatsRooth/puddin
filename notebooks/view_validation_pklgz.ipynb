# %%
import pandas as pd
from pathlib import Path
from datetime import datetime

# %%
validation_info_path = Path("/share/compling/data/puddin/info/all-pcc-texts_status.pkl.gz")
puddin_info = pd.read_pickle(validation_info_path)
puddin_info.sample(5)
# Out:
#                                   conll_id data_group excl_type  true_fail  \
# raw_id
# pcc_val_05808    pcc_eng_val_1.3558_x05808        val      <NA>      False
# pcc_test_17547                        <NA>       test      punc      False
# pcc_test_01738                        <NA>       test      html      False
# pcc_val_25247                         <NA>        val     a0wrd      False
# pcc_test_09342  pcc_eng_test_1.5813_x09342       test      <NA>      False
#
#                 success           slice  missing
# raw_id
# pcc_val_05808      True   pcc_eng_val_1    False
# pcc_test_17547    False            <NA>    False
# pcc_test_01738    False            <NA>    False
# pcc_val_25247     False            <NA>    False
# pcc_test_09342     True  pcc_eng_test_1    False

# %%
puddin_info.describe()
# Out:
#        true_fail
# count     105582
# unique         1
# top        False
# freq      105582

# %%
valid_info_time = validation_info_path.stat().st_mtime
datetime.fromtimestamp(valid_info_time).ctime()
# Out:
# 'Tue Aug  9 21:41:57 2022'

# %%
val_excl_times = {ef.stem: ef.stat().st_mtime for ef in Path('/share/compling/data/puddin/pile_exclusions/validated/').glob('*excl*')}
for k, v in val_excl_times.items(): 
    print(k.split('_')[1], datetime.fromtimestamp(v).ctime(), sep='\t>\t')
# Out:
# 05	>	Tue Aug  9 00:00:09 2022
# 07	>	Mon Aug  8 23:59:42 2022
# 02	>	Tue Aug  9 00:04:50 2022
# 06	>	Tue Aug  9 00:18:52 2022
# 00	>	Tue Aug  9 00:20:41 2022
# 04	>	Tue Aug  9 00:20:53 2022
# 03	>	Tue Aug  9 00:24:50 2022
# 01	>	Sun Aug  7 02:14:44 2022
# 09	>	Sun Aug  7 02:34:38 2022
# 08	>	Sun Aug  7 02:41:05 2022
# 11	>	Sun Aug  7 02:46:41 2022
# 12	>	Sun Aug  7 02:47:41 2022
# 14	>	Sun Aug  7 03:13:15 2022
# 16	>	Sun Aug  7 03:29:53 2022
# 13	>	Sun Aug  7 03:30:02 2022
# 17	>	Sun Aug  7 03:41:32 2022
# 19	>	Sun Aug  7 03:56:46 2022
# 18	>	Sun Aug  7 03:57:53 2022
# 15	>	Sun Aug  7 04:01:05 2022
# 10	>	Sun Aug  7 04:05:07 2022
# 22	>	Sun Aug  7 04:38:43 2022
# 21	>	Sun Aug  7 04:44:10 2022
# 20	>	Sun Aug  7 04:50:11 2022
# 26	>	Sun Aug  7 05:03:54 2022
# 27	>	Sun Aug  7 05:04:04 2022
# 24	>	Sun Aug  7 05:04:54 2022
# 23	>	Sun Aug  7 05:09:54 2022
# 28	>	Sun Aug  7 05:18:18 2022
# 25	>	Sun Aug  7 05:18:20 2022
# 29	>	Sun Aug  7 05:19:22 2022
# val	>	Tue Aug  9 21:41:55 2022
# test	>	Tue Aug  9 21:41:55 2022

# %%
if max(val_excl_times.values()) > valid_info_time: 
    print('Validation info is obsolete!')

# %%
sample_status_df = pd.read_pickle(
    '/share/compling/data/puddin/info/validation_by_group/03-pcc_status.pkl.gz')
sample_excl_inv = pd.read_pickle(
    '/share/compling/data/puddin/info/validation_by_group/03_invalid-excl.pkl.gz')

# %%
sample_excl_inv
# Out:
# Empty DataFrame
# Columns: [slice_id, excl_type, text, pile_set_name, pile_set_code, data_origin_fpath, dataframe_fpath, slice_numstr, recorded_fail, row_ix, invalid]
# Index: []

# %%
sample_status_df
# Out:
#                                     conll_id data_group excl_type  \
# raw_id
# pcc_03_0000001                          <NA>         03      punc
# pcc_03_0000002                          <NA>         03      punc
# pcc_03_0000003                          <NA>         03     a0wrd
# pcc_03_0000004  pcc_eng_03_001.0001_x0000004         03      <NA>
# pcc_03_0000005  pcc_eng_03_001.0002_x0000005         03      <NA>
# ...                                      ...        ...       ...
# pcc_03_1748466                          <NA>         03      punc
# pcc_03_1748467  pcc_eng_03_108.9933_x1748467         03      <NA>
# pcc_03_1748468  pcc_eng_03_108.9934_x1748468         03      <NA>
# pcc_03_1748469  pcc_eng_03_108.9935_x1748469         03      <NA>
# pcc_03_1748470                          <NA>         03     a0wrd
#
#                 recorded_fail  success           slice  missing
# raw_id
# pcc_03_0000001          False    False            <NA>    False
# pcc_03_0000002          False    False            <NA>    False
# pcc_03_0000003          False    False            <NA>    False
# pcc_03_0000004          False     True  pcc_eng_03_001    False
# pcc_03_0000005          False     True  pcc_eng_03_001    False
# ...                       ...      ...             ...      ...
# pcc_03_1748466          False    False            <NA>    False
# pcc_03_1748467          False     True  pcc_eng_03_108    False
# pcc_03_1748468          False     True  pcc_eng_03_108    False
# pcc_03_1748469          False     True  pcc_eng_03_108    False
# pcc_03_1748470          False    False            <NA>    False
#
# [1748470 rows x 7 columns]

# %%
sample_val_excl = pd.read_pickle(
    '/share/compling/data/puddin/pile_exclusions/validated/pile_01_Pile-CC_excl.pkl.gz')

# %%
sample_val_excl
# Out:
#                pile_set_name pile_set_code  \
# pcc_01_0380751       Pile-CC           Pcc
# pcc_01_0458268       Pile-CC           Pcc
# pcc_01_0537953       Pile-CC           Pcc
# pcc_01_0540607       Pile-CC           Pcc
# pcc_01_0674163       Pile-CC           Pcc
# ...                      ...           ...
# pcc_01_1747229       Pile-CC           Pcc
# pcc_01_1747232       Pile-CC           Pcc
# pcc_01_1747241       Pile-CC           Pcc
# pcc_01_1747243       Pile-CC           Pcc
# pcc_01_1747245       Pile-CC           Pcc
#
#                                        data_origin_fpath  \
# pcc_01_0380751  /share/compling/data/pile/train/01.jsonl
# pcc_01_0458268  /share/compling/data/pile/train/01.jsonl
# pcc_01_0537953  /share/compling/data/pile/train/01.jsonl
# pcc_01_0540607  /share/compling/data/pile/train/01.jsonl
# pcc_01_0674163  /share/compling/data/pile/train/01.jsonl
# ...                                                  ...
# pcc_01_1747229  /share/compling/data/pile/train/01.jsonl
# pcc_01_1747232  /share/compling/data/pile/train/01.jsonl
# pcc_01_1747241  /share/compling/data/pile/train/01.jsonl
# pcc_01_1747243  /share/compling/data/pile/train/01.jsonl
# pcc_01_1747245  /share/compling/data/pile/train/01.jsonl
#
#                                                   dataframe_fpath  \
# pcc_01_0380751  /share/compling/data/puddin/pile_tables/pile_0...
# pcc_01_0458268  /share/compling/data/puddin/pile_tables/pile_0...
# pcc_01_0537953  /share/compling/data/puddin/pile_tables/pile_0...
# pcc_01_0540607  /share/compling/data/puddin/pile_tables/pile_0...
# pcc_01_0674163  /share/compling/data/puddin/pile_tables/pile_0...
# ...                                                           ...
# pcc_01_1747229  /share/compling/data/puddin/pile_tables/pile_0...
# pcc_01_1747232  /share/compling/data/puddin/pile_tables/pile_0...
# pcc_01_1747241  /share/compling/data/puddin/pile_tables/pile_0...
# pcc_01_1747243  /share/compling/data/puddin/pile_tables/pile_0...
# pcc_01_1747245  /share/compling/data/puddin/pile_tables/pile_0...
#
#                                                              text  \
# pcc_01_0380751  The Central Seattle Community Council Federati...
# pcc_01_0458268  GAAP net loss of $2.50 per share includes cost...
# pcc_01_0537953  Brazilian Portuguese Translation Professional ...
# pcc_01_0540607  If you are in the Charlotte, Va, area this fal...
# pcc_01_0674163  Nuverra Announces Fourth Quarter And Full Year...
# ...                                                           ...
# pcc_01_1747229  LeAnn Rimes and husband Eddie Cibrian both che...
# pcc_01_1747232  Meet Tony Soprano: your average,middle-aged bu...
# pcc_01_1747241  It may be April Fools’ Day, but small business...
# pcc_01_1747243  As title stated, what is interesting is that (...
# pcc_01_1747245  Heating Oil (HO1) Down $0.01 Over Past 4 Hours...
#
#                slice_numstr excl_type                      slice_id  \
# pcc_01_0380751          024      fail  pcc_eng_01_024.5378_x0380751
# pcc_01_0458268          029      fail  pcc_eng_01_029.3375_x0458268
# pcc_01_0537953          034      fail  pcc_eng_01_034.2908_x0537953
# pcc_01_0540607          034      fail  pcc_eng_01_034.4559_x0540607
# pcc_01_0674163          042      fail  pcc_eng_01_042.7228_x0674163
# ...                     ...       ...                           ...
# pcc_01_1747229          NaN       NaN                          <NA>
# pcc_01_1747232          NaN       NaN                          <NA>
# pcc_01_1747241          NaN       NaN                          <NA>
# pcc_01_1747243          NaN       NaN                          <NA>
# pcc_01_1747245          NaN       NaN                          <NA>
#
#                 recorded_fail   row_ix  invalid
# pcc_01_0380751           True        0    False
# pcc_01_0458268           True        1    False
# pcc_01_0537953           True        2    False
# pcc_01_0540607           True        3    False
# pcc_01_0674163           True        4    False
# ...                       ...      ...      ...
# pcc_01_1747229          False  1747228    False
# pcc_01_1747232          False  1747231    False
# pcc_01_1747241          False  1747240    False
# pcc_01_1747243          False  1747242    False
# pcc_01_1747245          False  1747244    False
#
# [666247 rows x 11 columns]

# %%
sample_orig_excl = pd.read_pickle(
    '/share/compling/data/puddin/pile_exclusions/pile_01_Pile-CC_excl.pkl.gz')

# %%
sample_orig_excl
# Out:
#            text_id pile_set_name pile_set_code  \
# 0   pcc_01_0380751       Pile-CC           Pcc
# 1   pcc_01_0458268       Pile-CC           Pcc
# 2   pcc_01_0537953       Pile-CC           Pcc
# 3   pcc_01_0540607       Pile-CC           Pcc
# 4   pcc_01_0674163       Pile-CC           Pcc
# 5   pcc_01_0796114       Pile-CC           Pcc
# 6   pcc_01_0846931       Pile-CC           Pcc
# 7   pcc_01_0977232       Pile-CC           Pcc
# 8   pcc_01_0977447       Pile-CC           Pcc
# 9   pcc_01_1011882       Pile-CC           Pcc
# 10  pcc_01_1022309       Pile-CC           Pcc
# 11  pcc_01_1029312       Pile-CC           Pcc
# 12  pcc_01_1074375       Pile-CC           Pcc
# 13  pcc_01_1135025       Pile-CC           Pcc
# 14  pcc_01_1207275       Pile-CC           Pcc
# 15  pcc_01_1241486       Pile-CC           Pcc
# 16  pcc_01_1260450       Pile-CC           Pcc
# 17  pcc_01_1296173       Pile-CC           Pcc
# 18  pcc_01_1347448       Pile-CC           Pcc
# 19  pcc_01_1352790       Pile-CC           Pcc
# 20  pcc_01_1373602       Pile-CC           Pcc
# 21  pcc_01_1383037       Pile-CC           Pcc
# 22  pcc_01_1404730       Pile-CC           Pcc
# 23  pcc_01_1429907       Pile-CC           Pcc
# 24  pcc_01_1609335       Pile-CC           Pcc
# 25  pcc_01_1646937       Pile-CC           Pcc
# 26  pcc_01_1714679       Pile-CC           Pcc
# 27  pcc_01_1744050       Pile-CC           Pcc
# 28  pcc_01_0537953       Pile-CC           Pcc
# 29  pcc_01_0540607       Pile-CC           Pcc
# 30  pcc_01_0977232       Pile-CC           Pcc
# 31  pcc_01_0977447       Pile-CC           Pcc
# 32  pcc_01_1022309       Pile-CC           Pcc
# 33  pcc_01_1347448       Pile-CC           Pcc
#
#                            data_origin_fpath  \
# 0   /share/compling/data/pile/train/01.jsonl
# 1   /share/compling/data/pile/train/01.jsonl
# 2   /share/compling/data/pile/train/01.jsonl
# 3   /share/compling/data/pile/train/01.jsonl
# 4   /share/compling/data/pile/train/01.jsonl
# 5   /share/compling/data/pile/train/01.jsonl
# 6   /share/compling/data/pile/train/01.jsonl
# 7   /share/compling/data/pile/train/01.jsonl
# 8   /share/compling/data/pile/train/01.jsonl
# 9   /share/compling/data/pile/train/01.jsonl
# 10  /share/compling/data/pile/train/01.jsonl
# 11  /share/compling/data/pile/train/01.jsonl
# 12  /share/compling/data/pile/train/01.jsonl
# 13  /share/compling/data/pile/train/01.jsonl
# 14  /share/compling/data/pile/train/01.jsonl
# 15  /share/compling/data/pile/train/01.jsonl
# 16  /share/compling/data/pile/train/01.jsonl
# 17  /share/compling/data/pile/train/01.jsonl
# 18  /share/compling/data/pile/train/01.jsonl
# 19  /share/compling/data/pile/train/01.jsonl
# 20  /share/compling/data/pile/train/01.jsonl
# 21  /share/compling/data/pile/train/01.jsonl
# 22  /share/compling/data/pile/train/01.jsonl
# 23  /share/compling/data/pile/train/01.jsonl
# 24  /share/compling/data/pile/train/01.jsonl
# 25  /share/compling/data/pile/train/01.jsonl
# 26  /share/compling/data/pile/train/01.jsonl
# 27  /share/compling/data/pile/train/01.jsonl
# 28  /share/compling/data/pile/train/01.jsonl
# 29  /share/compling/data/pile/train/01.jsonl
# 30  /share/compling/data/pile/train/01.jsonl
# 31  /share/compling/data/pile/train/01.jsonl
# 32  /share/compling/data/pile/train/01.jsonl
# 33  /share/compling/data/pile/train/01.jsonl
#
#                                       dataframe_fpath  \
# 0   /share/compling/data/puddin/pile_tables/pile_0...
# 1   /share/compling/data/puddin/pile_tables/pile_0...
# 2   /share/compling/data/puddin/pile_tables/pile_0...
# 3   /share/compling/data/puddin/pile_tables/pile_0...
# 4   /share/compling/data/puddin/pile_tables/pile_0...
# 5   /share/compling/data/puddin/pile_tables/pile_0...
# 6   /share/compling/data/puddin/pile_tables/pile_0...
# 7   /share/compling/data/puddin/pile_tables/pile_0...
# 8   /share/compling/data/puddin/pile_tables/pile_0...
# 9   /share/compling/data/puddin/pile_tables/pile_0...
# 10  /share/compling/data/puddin/pile_tables/pile_0...
# 11  /share/compling/data/puddin/pile_tables/pile_0...
# 12  /share/compling/data/puddin/pile_tables/pile_0...
# 13  /share/compling/data/puddin/pile_tables/pile_0...
# 14  /share/compling/data/puddin/pile_tables/pile_0...
# 15  /share/compling/data/puddin/pile_tables/pile_0...
# 16  /share/compling/data/puddin/pile_tables/pile_0...
# 17  /share/compling/data/puddin/pile_tables/pile_0...
# 18  /share/compling/data/puddin/pile_tables/pile_0...
# 19  /share/compling/data/puddin/pile_tables/pile_0...
# 20  /share/compling/data/puddin/pile_tables/pile_0...
# 21  /share/compling/data/puddin/pile_tables/pile_0...
# 22  /share/compling/data/puddin/pile_tables/pile_0...
# 23  /share/compling/data/puddin/pile_tables/pile_0...
# 24  /share/compling/data/puddin/pile_tables/pile_0...
# 25  /share/compling/data/puddin/pile_tables/pile_0...
# 26  /share/compling/data/puddin/pile_tables/pile_0...
# 27  /share/compling/data/puddin/pile_tables/pile_0...
# 28  /share/compling/data/puddin/pile_tables/pile_0...
# 29  /share/compling/data/puddin/pile_tables/pile_0...
# 30  /share/compling/data/puddin/pile_tables/pile_0...
# 31  /share/compling/data/puddin/pile_tables/pile_0...
# 32  /share/compling/data/puddin/pile_tables/pile_0...
# 33  /share/compling/data/puddin/pile_tables/pile_0...
#
#                                                  text slice_numstr excl_type  \
# 0   The Central Seattle Community Council Federati...          024      fail
# 1   GAAP net loss of $2.50 per share includes cost...          029      fail
# 2   Brazilian Portuguese Translation Professional ...          034      fail
# 3   If you are in the Charlotte, Va, area this fal...          034      fail
# 4   Nuverra Announces Fourth Quarter And Full Year...          042      fail
# 5   Wandering to find my way Home
#
# Month: June 201...          050      fail
# 6   Let the discussions begin! I've taken all the ...          053      fail
# 7   Press Release
#
# Fulton Financial Reports Fourth...          061      fail
# 8   Home Tutors For Business Law
#
# Home Tutors For ...          061      fail
# 9   HOUSTON--(BUSINESS WIRE)--Forum Energy Technol...          063      fail
# 10  Chevigny Holiday home for 14 people in Etais l...          064      fail
# 11  Thursday, 30 June 2016
#
# Predictions! Predictio...          064      fail
# 12  Organization which receives a substantial part...          067      fail
# 13  Education: A Vital Issue in Election 2000
#
# Pub...          071      fail
# 14  {"project": {
# "benefits": "Potential NASA Comm...          075      fail
# 15  Demonstrates basic rules of how to read a cand...          077      fail
# 16  IGS School Yearbooks
#
# IGS has a collection of ...          078      fail
# 17  Guaranteed Tuition Plans
#
# The following tuitio...          081      fail
# 18  Data Summary
#
# John Ball Zoo and Grand Rapids P...          084      fail
# 19  The power rating system is based on recent gam...          084      fail
# 20  What is the GDP of Hong Kong?
#
# The information...          085      fail
# 21  Videos
#
# Do I Wanna Know?
#
# COMMENT (59)
#
# Kellyl...          086      fail
# 22  A LIST OF BAILLIES, PROVOSTS & LORD PROVOSTS O...          087      fail
# 23  Helmerich & Payne, Inc. Announces First Quarte...          089      fail
# 24  Dime Community Bancshares, Inc. Reports Earnin...          100      fail
# 25  This transcript may be automatically generated...          102      fail
# 26  INTRODUCTION TO MICROECONOMICS
# Presented by Mu...          107      fail
# 27  Articles
#
# Keywords
#
# Independent Bank Corporati...          108      fail
# 28  Brazilian Portuguese Translation Professional ...          034      fail
# 29  If you are in the Charlotte, Va, area this fal...          034      fail
# 30  Press Release
#
# Fulton Financial Reports Fourth...          061      fail
# 31  Home Tutors For Business Law
#
# Home Tutors For ...          061      fail
# 32  Chevigny Holiday home for 14 people in Etais l...          064      fail
# 33  Data Summary
#
# John Ball Zoo and Grand Rapids P...          084      fail
#
#                          slice_id
# 0    pcc_eng_01_024.5378_x0380751
# 1    pcc_eng_01_029.3375_x0458268
# 2    pcc_eng_01_034.2908_x0537953
# 3    pcc_eng_01_034.4559_x0540607
# 4    pcc_eng_01_042.7228_x0674163
# 5    pcc_eng_01_050.2682_x0796114
# 6    pcc_eng_01_053.3984_x0846931
# 7    pcc_eng_01_061.4203_x0977232
# 8    pcc_eng_01_061.4338_x0977447
# 9    pcc_eng_01_063.5543_x1011882
# 10   pcc_eng_01_064.2080_x1022309
# 11   pcc_eng_01_064.6455_x1029312
# 12   pcc_eng_01_067.4183_x1074375
# 13   pcc_eng_01_071.1660_x1135025
# 14   pcc_eng_01_075.6441_x1207275
# 15   pcc_eng_01_077.7789_x1241486
# 16   pcc_eng_01_078.9532_x1260450
# 17   pcc_eng_01_081.1641_x1296173
# 18   pcc_eng_01_084.3281_x1347448
# 19   pcc_eng_01_084.6613_x1352790
# 20   pcc_eng_01_085.9609_x1373602
# 21   pcc_eng_01_086.5405_x1383037
# 22   pcc_eng_01_087.8784_x1404730
# 23   pcc_eng_01_089.4385_x1429907
# 24   pcc_eng_01_100.5592_x1609335
# 25   pcc_eng_01_102.9020_x1646937
# 26  pcc_eng_01_107.00915_x1714679
# 27  pcc_eng_01_108.08551_x1744050
# 28   pcc_eng_01_034.2908_x0537953
# 29   pcc_eng_01_034.4559_x0540607
# 30   pcc_eng_01_061.4203_x0977232
# 31   pcc_eng_01_061.4338_x0977447
# 32   pcc_eng_01_064.2080_x1022309
# 33   pcc_eng_01_084.3281_x1347448
