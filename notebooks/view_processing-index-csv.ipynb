# %% [markdown]
# # Full Processing Stats from the Cluster
#
# This notebook loads the processing info for data slices completely processed by `script/parse_pile.py`.

# %%
import pandas as pd

# %%
info = pd.read_csv(
    '/home/arh234/projects/puddin/cluster_log_info/processing-index_at2022-04-20-14:40.csv', 
    usecols=['slice_name', 'total_texts', 'data_origin_group', 
             'slice_number', 'started_at', 'finished_at', 'parsing_time', 
             'final_df_path', 'final_slice_path', 'conllu_path']
    ).convert_dtypes().loc[:,
        ['slice_name', 'total_texts', 'data_origin_group', 
             'slice_number', 'started_at', 'finished_at', 'parsing_time', 
             'final_df_path', 'final_slice_path', 'conllu_path']]
time_info = info.columns.str.endswith('at')
info.loc[:, time_info] = info.loc[:, time_info].apply(pd.to_datetime)

info = info.assign(days=pd.to_numeric(info.parsing_time.str.split(' ').str.get(0)), 
                   time=info.parsing_time.str.split(' ').str.get(-1).apply(pd.to_timedelta), 
                   slice_number = info.slice_number.apply(pd.to_numeric))
info = info.set_index(['slice_name','started_at'])

# %%
info.sort_values(['time', 'total_texts'])
# Out:
#                                 total_texts data_origin_group  slice_number  \
# slice_name started_at
# Pcc29_9    2022-04-13 04:52:53         9999                29             9
# Pcc29_011  2022-04-19 23:14:23         9999                29            11
# Pcc29_010  2022-04-19 22:40:58         9999                29            10
# Pcc29_013  2022-04-20 00:22:19         9999                29            13
# Pcc02_022  2022-04-20 12:20:30         9999                 2            22
# ...                                     ...               ...           ...
# Pcc10_2    2022-04-13 03:48:59         9999                10             2
# Pcc16_2    2022-04-13 04:45:14         9999                16             2
# Pcc11_2    2022-04-13 03:29:59         9999                11             2
# val_2      2022-03-23 22:35:15        11306               val             2
# Pcc29_8    2022-04-13 03:46:33         9999                29             8
#
# ...

# %%
info.time.describe()
# Out:
# count                          658
# mean     0 days 00:44:12.106382978
# std      0 days 00:05:01.769375167
# min                0 days 00:05:50
# 25%         0 days 00:41:27.250000
# 50%                0 days 00:43:26
# 75%         0 days 00:46:37.750000
# max                0 days 01:06:20
# Name: time, dtype: object

# %%
info.data_origin_group.unique()
# Out:
# <StringArray>
# ['test',  'val',   '29',   '28',   '11',   '10',   '09',   '08',   '05',
#    '03',   '01',   '12',   '13',   '04',   '02',   '06',   '16',   '17',
#    '15',   '00',   '07',    '8',    '0',    '9',    '7',    '3',    '6',
#     '5',    '2',   '14',    '1',   '20',   '25',   '23',   '24',   '18',
#    '19',   '26']
# Length: 38, dtype: string

# %%
info.loc[info.slice_number == info.slice_number.max(), ['finished_at', 'total_texts', 'time']]
# Out:
#                                        finished_at  total_texts  \
# slice_name started_at
# Pcc11_047  2022-04-20 13:55:47 2022-04-20 14:39:36         9999
#
#                                           time
# slice_name started_at
# Pcc11_047  2022-04-20 13:55:47 0 days 00:43:49
