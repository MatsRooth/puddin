# %% [markdown]
# # Full Processing Stats from the Cluster
#
# This notebook loads the processing info for data slices completely processed by `script/parse_pile.py`.

# %%
import pandas as pd
from pathlib import Path
from datetime import datetime
tstamp = datetime.fromtimestamp
DATA_DIR = Path('/share/compling/data/puddin')

# %%
info_full = pd.read_csv('data/all-completed-slices_meta-index.csv')
# process_cols = ['slice_name', 'total_texts', 'data_origin_group', 'slice_number',
#                 'started_at', 'finished_at', 'parsing_time',
#                 'final_df_path', 'final_slice_path', 'conllu_path']
# info = info_full.loc[:, process_cols].convert_dtypes()
info = info_full.convert_dtypes()

info = info.assign(slice_number_str = info.slice_number.astype('string').apply(lambda s: s.zfill(3)),
                   data_origin_group = info.data_origin_group.apply(lambda s: s.zfill(2)))

time_cols = info.columns.str.endswith('at')
time_info = info.loc[:, time_cols].apply(pd.to_datetime)
info.loc[:, time_cols] = time_info
info = info.assign(days=pd.to_numeric(info.parsing_time.str.split(' ').str.get(0)), 
                   time=info.parsing_time.str.split(' ').str.get(-1).apply(pd.to_timedelta), 
                   slice_number = info.slice_number.apply(lambda n: pd.to_numeric(n, downcast='unsigned')))

info = info.assign(seconds=info.time.apply(lambda td: pd.to_numeric(round(td.total_seconds()),downcast='unsigned')))
ix = pd.Series(info.index.astype('string')).apply(lambda i: i.zfill(len(str(info.index.max()))))
info = info.assign(record=info.data_origin_group.str.upper().apply(lambda s: s[:2]) +'-'+info.slice_number_str+'-'+ix)
info = info.set_index('record')
info_load_full = info

# %% [markdown]
# Add size and last modification time for final conllu file paths

# %%
info = info_load_full

# %%
info = info.assign(
    kept_df_mtime=info.final_df_path.apply(
        lambda p: pd.Timestamp.fromtimestamp(DATA_DIR.joinpath(Path(p)).stat().st_mtime)),
    excl_df_mtime=info.exclusions_path.apply(
        lambda p: pd.Timestamp.fromtimestamp(DATA_DIR.joinpath(Path(p)).stat().st_mtime)),
    slice_df_mtime=info.tmp_slice_path.apply(
        lambda p: pd.Timestamp.fromtimestamp( DATA_DIR.joinpath(Path(p)).stat().st_mtime)),
    conllu_mtime=info.conllu_path.apply(
        lambda p: pd.Timestamp.fromtimestamp(DATA_DIR.joinpath(Path(p)).stat().st_mtime)),

    kept_df_gzMB=info.final_df_path.apply(
        lambda p: (DATA_DIR.joinpath(Path(p)).stat().st_size) / 1048576).round(2),
    excl_df_gzMB=info.exclusions_path.apply(
        lambda p: (DATA_DIR.joinpath(Path(p)).stat().st_size) / 1048576).round(2),
    slice_df_gzMB=info.tmp_slice_path.apply(
        lambda p: (DATA_DIR.joinpath(Path(p)).stat().st_size) / 1048576).round(2),
    conllu_MB=info.conllu_path.apply(
        lambda p: (DATA_DIR.joinpath(Path(p)).stat().st_size) / 1048576).round(2)
)

# %%
dtcols =  info.select_dtypes(include='datetime')
info.loc[:,dtcols.columns] = dtcols.apply(lambda c: c.dt.round("min"))

# %%
# info = info_load_full
info.sample(5)[[c for c in info.columns if c.endswith(('B', 'mtime', 'finished_at'))]]
# Out:
#                     finished_at       kept_df_mtime       excl_df_mtime  \
# record
# 19-057-3180 2022-05-31 00:25:00 2022-04-20 02:15:00 2022-06-01 07:50:00
# 22-009-1722 2022-04-28 07:44:00 2022-04-28 00:11:00 2022-05-27 21:50:00
# 27-098-2729 2022-05-05 04:18:00 2022-04-28 01:25:00 2022-05-05 09:31:00
# 04-053-3302 2022-06-01 21:11:00 2022-04-13 03:36:00 2022-06-03 07:10:00
# 12-066-2817 2022-05-24 22:18:00 2022-04-13 03:31:00 2022-05-24 21:42:00
#
#                  slice_df_mtime        conllu_mtime  kept_df_gzMB  \
# record
# 19-057-3180 2022-04-20 02:18:00 2022-05-31 00:25:00       1012.36
# 22-009-1722 2022-04-28 00:12:00 2022-05-25 02:15:00       1013.06
# 27-098-2729 2022-04-28 01:30:00 2022-05-05 04:18:00       1014.82
# 04-053-3302 2022-04-13 03:39:00 2022-06-01 21:11:00       1013.64
# 12-066-2817 2022-04-13 03:35:00 2022-05-24 22:18:00       1012.83
#
#              excl_df_gzMB  slice_df_gzMB  conllu_MB
# record
# 19-057-3180       1754.32           9.45     384.65
# 22-009-1722       2242.64           9.36     380.02
# 27-098-2729       1749.68           9.47     384.21
# 04-053-3302       1742.39           9.35     378.25
# 12-066-2817       1753.77           9.41     381.20

# %%
# was_replaced = info.duplicated(keep=False, subset=['data_origin_group', 'slice_number', 'final_slice_path', 'conllu_path'])
# info.loc[was_replaced, :].sort_values('record')
was_replaced = info.duplicated(keep='last', subset=['data_origin_group', 'slice_number', 'conllu_path'])
replaced = info.loc[was_replaced,:].sort_values('record')

# %% [markdown]
# save processing records that have been replaced to a separate file, `replaced_slice-index-records.csv`, and remove them from the main `info` dataframe:

# %%
replaced.to_csv('data/replaced_slice-index-records.csv')
info = info.loc[~was_replaced,:]
info_load = info

# %%
# info = info_load

# %%
info.sort_values(['seconds', 'total_texts'], ascending=False)
# Out:
#             slice_name  total_texts                 first_text_id  \
# record
# 24-040-2011  Pcc24_040         9999  pcc_eng_24_040.0001_x0630363
# 18-091-2816  Pcc18_091         9999  pcc_eng_18_091.0001_x1457489
# 10-024-1558  Pcc10_024         9999  pcc_eng_10_024.0001_x0371544
# 10-048-1630  Pcc10_048         9999  pcc_eng_10_048.0001_x0760323
# 10-026-1573  Pcc10_026         9999  pcc_eng_10_026.0001_x0403864
# ...                ...          ...                           ...
# 12-051-2564  Pcc12_051         9999  pcc_eng_12_051.0001_x0808148
# 12-047-2535  Pcc12_047         9999  pcc_eng_12_047.0001_x0743541
# 12-050-2556  Pcc12_050         9999  pcc_eng_12_050.0001_x0792018
# 12-045-2523  Pcc12_045         9999  pcc_eng_12_045.0001_x0711367
# 29-009-3370  Pcc29_009         9999  pcc_eng_29_009.0001_x0129300
#
#                              last_text_id  \
# record
# 24-040-2011  pcc_eng_24_040.9999_x0646500
# 18-091-2816  pcc_eng_18_091.9999_x1473649
# 10-024-1558  pcc_eng_10_024.9999_x0387720
# 10-048-1630  pcc_eng_10_048.9999_x0776333
# 10-026-1573  pcc_eng_10_026.9999_x0420194
# ...                                   ...
# 12-051-2564  pcc_eng_12_051.9999_x0824308
# 12-047-2535  pcc_eng_12_047.9999_x0759569
# 12-050-2556  pcc_eng_12_050.9999_x0808147
# 12-045-2523  pcc_eng_12_045.9999_x0727554
# 29-009-3370  pcc_eng_29_009.9999_x0145503
#
#                                                 tmp_slice_path  \
# record
# 24-040-2011  pile_tables/slices/Pcc24/tmp/pile_24-040_Pile-...
# 18-091-2816  pile_tables/slices/Pcc18/tmp/pile_18-091_Pile-...
# 10-024-1558  pile_tables/slices/Pcc10/tmp/pile_10-024_Pile-...
# 10-048-1630  pile_tables/slices/Pcc10/tmp/pile_10-048_Pile-...
# 10-026-1573  pile_tables/slices/Pcc10/tmp/pile_10-026_Pile-...
# ...                                                        ...
# 12-051-2564  pile_tables/slices/Pcc12/tmp/pile_12-051_Pile-...
# 12-047-2535  pile_tables/slices/Pcc12/tmp/pile_12-047_Pile-...
# 12-050-2556  pile_tables/slices/Pcc12/tmp/pile_12-050_Pile-...
# 12-045-2523  pile_tables/slices/Pcc12/tmp/pile_12-045_Pile-...
# 29-009-3370  pile_tables/slices/Pcc29/tmp/pile_29-009_Pile-...
#
#                                               final_slice_path  \
# record
# 24-040-2011  pile_tables/slices/Pcc24/pile_24-040_Pile-CC_d...
# 18-091-2816  pile_tables/slices/Pcc18/pile_18-091_Pile-CC_d...
# 10-024-1558  pile_tables/slices/Pcc10/pile_10-024_Pile-CC_d...
# 10-048-1630  pile_tables/slices/Pcc10/pile_10-048_Pile-CC_d...
# 10-026-1573  pile_tables/slices/Pcc10/pile_10-026_Pile-CC_d...
# ...                                                        ...
# 12-051-2564  pile_tables/slices/Pcc12/pile_12-051_Pile-CC_d...
# 12-047-2535  pile_tables/slices/Pcc12/pile_12-047_Pile-CC_d...
# 12-050-2556  pile_tables/slices/Pcc12/pile_12-050_Pile-CC_d...
# 12-045-2523  pile_tables/slices/Pcc12/pile_12-045_Pile-CC_d...
# 29-009-3370  pile_tables/slices/Pcc29/pile_29-009_Pile-CC_d...
#
#                                    conllu_path  \
# record
# 24-040-2011  Pcc24.conll/pcc_eng_24-040.conllu
# 18-091-2816  Pcc18.conll/pcc_eng_18-091.conllu
# 10-024-1558  Pcc10.conll/pcc_eng_10-024.conllu
# 10-048-1630  Pcc10.conll/pcc_eng_10-048.conllu
# 10-026-1573  Pcc10.conll/pcc_eng_10-026.conllu
# ...                                        ...
# 12-051-2564  Pcc12.conll/pcc_eng_12-051.conllu
# 12-047-2535  Pcc12.conll/pcc_eng_12-047.conllu
# 12-050-2556  Pcc12.conll/pcc_eng_12-050.conllu
# 12-045-2523  Pcc12.conll/pcc_eng_12-045.conllu
# 29-009-3370  Pcc29.conll/pcc_eng_29-009.conllu
#
#                                       origin_filepath data_origin_group  \
# record
# 24-040-2011  /share/compling/data/pile/train/24.jsonl                24
# 18-091-2816  /share/compling/data/pile/train/18.jsonl                18
# 10-024-1558  /share/compling/data/pile/train/10.jsonl                10
# 10-048-1630  /share/compling/data/pile/train/10.jsonl                10
# 10-026-1573  /share/compling/data/pile/train/10.jsonl                10
# ...                                               ...               ...
# 12-051-2564  /share/compling/data/pile/train/12.jsonl                12
# 12-047-2535  /share/compling/data/pile/train/12.jsonl                12
# 12-050-2556  /share/compling/data/pile/train/12.jsonl                12
# 12-045-2523  /share/compling/data/pile/train/12.jsonl                12
# 29-009-3370  /share/compling/data/pile/train/29.jsonl                29
#
#                                      final_df_path  ...            time  \
# record                                              ...
# 24-040-2011  pile_tables/pile_24_Pile-CC_df.pkl.gz  ... 0 days 01:30:27
# 18-091-2816  pile_tables/pile_18_Pile-CC_df.pkl.gz  ... 0 days 01:21:43
# 10-024-1558  pile_tables/pile_10_Pile-CC_df.pkl.gz  ... 0 days 01:20:55
# 10-048-1630  pile_tables/pile_10_Pile-CC_df.pkl.gz  ... 0 days 01:11:16
# 10-026-1573  pile_tables/pile_10_Pile-CC_df.pkl.gz  ... 0 days 01:10:44
# ...                                            ...  ...             ...
# 12-051-2564  pile_tables/pile_12_Pile-CC_df.pkl.gz  ... 0 days 00:25:26
# 12-047-2535  pile_tables/pile_12_Pile-CC_df.pkl.gz  ... 0 days 00:25:24
# 12-050-2556  pile_tables/pile_12_Pile-CC_df.pkl.gz  ... 0 days 00:25:23
# 12-045-2523  pile_tables/pile_12_Pile-CC_df.pkl.gz  ... 0 days 00:25:12
# 29-009-3370  pile_tables/pile_29_Pile-CC_df.pkl.gz  ... 0 days 00:01:40
#
#              seconds       kept_df_mtime       excl_df_mtime  \
# record
# 24-040-2011     5427 2022-04-20 01:41:00 2022-05-05 11:51:00
# 18-091-2816     4903 2022-04-20 01:52:00 2022-05-25 06:52:00
# 10-024-1558     4855 2022-04-13 02:54:00 2022-05-03 03:45:00
# 10-048-1630     4276 2022-04-13 02:54:00 2022-05-03 03:45:00
# 10-026-1573     4244 2022-04-13 02:54:00 2022-05-03 03:45:00
# ...              ...                 ...                 ...
# 12-051-2564     1526 2022-04-13 03:31:00 2022-05-24 21:42:00
# 12-047-2535     1524 2022-04-13 03:31:00 2022-05-24 21:42:00
# 12-050-2556     1523 2022-04-13 03:31:00 2022-05-24 21:42:00
# 12-045-2523     1512 2022-04-13 03:31:00 2022-05-24 21:42:00
# 29-009-3370      100 2022-03-27 02:12:00 2022-04-30 03:31:00
#
#                  slice_df_mtime        conllu_mtime  kept_df_gzMB  \
# record
# 24-040-2011 2022-04-20 01:43:00 2022-05-02 23:21:00       1013.42
# 18-091-2816 2022-04-20 01:56:00 2022-05-24 22:04:00       1010.50
# 10-024-1558 2022-04-13 02:55:00 2022-04-26 22:02:00       1015.61
# 10-048-1630 2022-04-13 02:56:00 2022-04-27 21:34:00       1015.61
# 10-026-1573 2022-04-13 02:55:00 2022-04-27 00:22:00       1015.61
# ...                         ...                 ...           ...
# 12-051-2564 2022-04-13 03:34:00 2022-05-04 14:14:00       1012.83
# 12-047-2535 2022-04-13 03:34:00 2022-05-04 12:16:00       1012.83
# 12-050-2556 2022-04-13 03:34:00 2022-05-04 13:42:00       1012.83
# 12-045-2523 2022-04-13 03:34:00 2022-05-04 11:25:00       1012.83
# 29-009-3370 2022-04-12 21:17:00 2022-06-22 18:19:00       1015.20
#
#             excl_df_gzMB  slice_df_gzMB conllu_MB
# record
# 24-040-2011      1750.89           9.74    397.72
# 18-091-2816      1758.81           9.34    379.33
# 10-024-1558      1740.48           9.66    391.74
# 10-048-1630      1740.48           9.54    389.63
# 10-026-1573      1740.48           9.48    384.32
# ...                  ...            ...       ...
# 12-051-2564      1753.77           9.31    379.22
# 12-047-2535      1753.77           9.37    380.66
# 12-050-2556      1753.77           9.44    381.85
# 12-045-2523      1753.77           9.30    378.61
# 29-009-3370         0.09           9.18    371.70
#
# [3246 rows x 27 columns]

# %%
sec_dstats = (info.seconds).describe()

lower = sec_dstats[4] + (sec_dstats[4] - sec_dstats[5]) *1.5
fast = info.loc[info.seconds < lower, :]
fast.sort_values('seconds')
# Out:
#             slice_name  total_texts                 first_text_id  \
# record
# 29-009-3370  Pcc29_009         9999  pcc_eng_29_009.0001_x0129300
# 12-045-2523  Pcc12_045         9999  pcc_eng_12_045.0001_x0711367
# 12-050-2556  Pcc12_050         9999  pcc_eng_12_050.0001_x0792018
# 12-047-2535  Pcc12_047         9999  pcc_eng_12_047.0001_x0743541
# 12-051-2564  Pcc12_051         9999  pcc_eng_12_051.0001_x0808148
# ...                ...          ...                           ...
# 12-059-2620  Pcc12_059         9999  pcc_eng_12_059.0001_x0937734
# 02-104-2982  Pcc02_104         9999  pcc_eng_02_104.0001_x1665566
# 02-091-2941  Pcc02_091         9999  pcc_eng_02_091.0001_x1455096
# 02-097-2961  Pcc02_097         9999  pcc_eng_02_097.0001_x1552144
# 02-102-2976  Pcc02_102         9999  pcc_eng_02_102.0001_x1633190
#
#                              last_text_id  \
# record
# 29-009-3370  pcc_eng_29_009.9999_x0145503
# 12-045-2523  pcc_eng_12_045.9999_x0727554
# 12-050-2556  pcc_eng_12_050.9999_x0808147
# 12-047-2535  pcc_eng_12_047.9999_x0759569
# 12-051-2564  pcc_eng_12_051.9999_x0824308
# ...                                   ...
# 12-059-2620  pcc_eng_12_059.9999_x0953936
# 02-104-2982  pcc_eng_02_104.9999_x1681747
# 02-091-2941  pcc_eng_02_091.9999_x1471268
# 02-097-2961  pcc_eng_02_097.9999_x1568272
# 02-102-2976  pcc_eng_02_102.9999_x1649368
#
#                                                 tmp_slice_path  \
# record
# 29-009-3370  pile_tables/slices/Pcc29/tmp/pile_29-009_Pile-...
# 12-045-2523  pile_tables/slices/Pcc12/tmp/pile_12-045_Pile-...
# 12-050-2556  pile_tables/slices/Pcc12/tmp/pile_12-050_Pile-...
# 12-047-2535  pile_tables/slices/Pcc12/tmp/pile_12-047_Pile-...
# 12-051-2564  pile_tables/slices/Pcc12/tmp/pile_12-051_Pile-...
# ...                                                        ...
# 12-059-2620  pile_tables/slices/Pcc12/tmp/pile_12-059_Pile-...
# 02-104-2982  pile_tables/slices/Pcc02/tmp/pile_02-104_Pile-...
# 02-091-2941  pile_tables/slices/Pcc02/tmp/pile_02-091_Pile-...
# 02-097-2961  pile_tables/slices/Pcc02/tmp/pile_02-097_Pile-...
# 02-102-2976  pile_tables/slices/Pcc02/tmp/pile_02-102_Pile-...
#
#                                               final_slice_path  \
# record
# 29-009-3370  pile_tables/slices/Pcc29/pile_29-009_Pile-CC_d...
# 12-045-2523  pile_tables/slices/Pcc12/pile_12-045_Pile-CC_d...
# 12-050-2556  pile_tables/slices/Pcc12/pile_12-050_Pile-CC_d...
# 12-047-2535  pile_tables/slices/Pcc12/pile_12-047_Pile-CC_d...
# 12-051-2564  pile_tables/slices/Pcc12/pile_12-051_Pile-CC_d...
# ...                                                        ...
# 12-059-2620  pile_tables/slices/Pcc12/pile_12-059_Pile-CC_d...
# 02-104-2982  pile_tables/slices/Pcc02/pile_02-104_Pile-CC_d...
# 02-091-2941  pile_tables/slices/Pcc02/pile_02-091_Pile-CC_d...
# 02-097-2961  pile_tables/slices/Pcc02/pile_02-097_Pile-CC_d...
# 02-102-2976  pile_tables/slices/Pcc02/pile_02-102_Pile-CC_d...
#
#                                    conllu_path  \
# record
# 29-009-3370  Pcc29.conll/pcc_eng_29-009.conllu
# 12-045-2523  Pcc12.conll/pcc_eng_12-045.conllu
# 12-050-2556  Pcc12.conll/pcc_eng_12-050.conllu
# 12-047-2535  Pcc12.conll/pcc_eng_12-047.conllu
# 12-051-2564  Pcc12.conll/pcc_eng_12-051.conllu
# ...                                        ...
# 12-059-2620  Pcc12.conll/pcc_eng_12-059.conllu
# 02-104-2982  Pcc02.conll/pcc_eng_02-104.conllu
# 02-091-2941  Pcc02.conll/pcc_eng_02-091.conllu
# 02-097-2961  Pcc02.conll/pcc_eng_02-097.conllu
# 02-102-2976  Pcc02.conll/pcc_eng_02-102.conllu
#
#                                       origin_filepath data_origin_group  \
# record
# 29-009-3370  /share/compling/data/pile/train/29.jsonl                29
# 12-045-2523  /share/compling/data/pile/train/12.jsonl                12
# 12-050-2556  /share/compling/data/pile/train/12.jsonl                12
# 12-047-2535  /share/compling/data/pile/train/12.jsonl                12
# 12-051-2564  /share/compling/data/pile/train/12.jsonl                12
# ...                                               ...               ...
# 12-059-2620  /share/compling/data/pile/train/12.jsonl                12
# 02-104-2982  /share/compling/data/pile/train/02.jsonl                02
# 02-091-2941  /share/compling/data/pile/train/02.jsonl                02
# 02-097-2961  /share/compling/data/pile/train/02.jsonl                02
# 02-102-2976  /share/compling/data/pile/train/02.jsonl                02
#
#                                      final_df_path  ...            time  \
# record                                              ...
# 29-009-3370  pile_tables/pile_29_Pile-CC_df.pkl.gz  ... 0 days 00:01:40
# 12-045-2523  pile_tables/pile_12_Pile-CC_df.pkl.gz  ... 0 days 00:25:12
# 12-050-2556  pile_tables/pile_12_Pile-CC_df.pkl.gz  ... 0 days 00:25:23
# 12-047-2535  pile_tables/pile_12_Pile-CC_df.pkl.gz  ... 0 days 00:25:24
# 12-051-2564  pile_tables/pile_12_Pile-CC_df.pkl.gz  ... 0 days 00:25:26
# ...                                            ...  ...             ...
# 12-059-2620  pile_tables/pile_12_Pile-CC_df.pkl.gz  ... 0 days 00:28:07
# 02-104-2982  pile_tables/pile_02_Pile-CC_df.pkl.gz  ... 0 days 00:28:12
# 02-091-2941  pile_tables/pile_02_Pile-CC_df.pkl.gz  ... 0 days 00:28:13
# 02-097-2961  pile_tables/pile_02_Pile-CC_df.pkl.gz  ... 0 days 00:28:13
# 02-102-2976  pile_tables/pile_02_Pile-CC_df.pkl.gz  ... 0 days 00:28:14
#
#              seconds       kept_df_mtime       excl_df_mtime  \
# record
# 29-009-3370      100 2022-03-27 02:12:00 2022-04-30 03:31:00
# 12-045-2523     1512 2022-04-13 03:31:00 2022-05-24 21:42:00
# 12-050-2556     1523 2022-04-13 03:31:00 2022-05-24 21:42:00
# 12-047-2535     1524 2022-04-13 03:31:00 2022-05-24 21:42:00
# 12-051-2564     1526 2022-04-13 03:31:00 2022-05-24 21:42:00
# ...              ...                 ...                 ...
# 12-059-2620     1687 2022-04-13 03:31:00 2022-05-24 21:42:00
# 02-104-2982     1692 2022-04-13 03:39:00 2022-05-26 10:38:00
# 02-091-2941     1693 2022-04-13 03:39:00 2022-05-26 10:38:00
# 02-097-2961     1693 2022-04-13 03:39:00 2022-05-26 10:38:00
# 02-102-2976     1694 2022-04-13 03:39:00 2022-05-26 10:38:00
#
#                  slice_df_mtime        conllu_mtime  kept_df_gzMB  \
# record
# 29-009-3370 2022-04-12 21:17:00 2022-06-22 18:19:00       1015.20
# 12-045-2523 2022-04-13 03:34:00 2022-05-04 11:25:00       1012.83
# 12-050-2556 2022-04-13 03:34:00 2022-05-04 13:42:00       1012.83
# 12-047-2535 2022-04-13 03:34:00 2022-05-04 12:16:00       1012.83
# 12-051-2564 2022-04-13 03:34:00 2022-05-04 14:14:00       1012.83
# ...                         ...                 ...           ...
# 12-059-2620 2022-04-13 03:34:00 2022-05-04 18:12:00       1012.83
# 02-104-2982 2022-04-13 03:44:00 2022-05-26 09:05:00       1015.80
# 02-091-2941 2022-04-13 03:43:00 2022-05-26 02:40:00       1015.80
# 02-097-2961 2022-04-13 03:43:00 2022-05-26 05:45:00       1015.80
# 02-102-2976 2022-04-13 03:44:00 2022-05-26 08:08:00       1015.80
#
#             excl_df_gzMB  slice_df_gzMB conllu_MB
# record
# 29-009-3370         0.09           9.18    371.70
# 12-045-2523      1753.77           9.30    378.61
# 12-050-2556      1753.77           9.44    381.85
# 12-047-2535      1753.77           9.37    380.66
# 12-051-2564      1753.77           9.31    379.22
# ...                  ...            ...       ...
# 12-059-2620      1753.77           9.39    380.56
# 02-104-2982      1753.59           9.30    377.82
# 02-091-2941      1753.59           9.37    379.79
# 02-097-2961      1753.59           9.36    380.30
# 02-102-2976      1753.59           9.40    381.88
#
# [76 rows x 27 columns]

# %%
upper = sec_dstats[6] + (sec_dstats[6] - sec_dstats[5]) * 1.5
slow = info.loc[info.seconds > upper, :]
slow.sort_values('seconds', ascending=False)[['slice_name', 'time', 'total_texts', 'conllu_path', 'conllu_MB', 'conllu_mtime', 'finished_at']]
# Out:
#             slice_name            time  total_texts  \
# record
# 24-040-2011  Pcc24_040 0 days 01:30:27         9999
# 18-091-2816  Pcc18_091 0 days 01:21:43         9999
# 10-024-1558  Pcc10_024 0 days 01:20:55         9999
# 10-048-1630  Pcc10_048 0 days 01:11:16         9999
# 10-026-1573  Pcc10_026 0 days 01:10:44         9999
# ...                ...             ...          ...
# 13-004-0098    Pcc13_4 0 days 00:48:51         9999
# 14-103-1600  Pcc14_103 0 days 00:48:44         9999
# 12-003-0079    Pcc12_3 0 days 00:48:43         9999
# 29-048-1752  Pcc29_048 0 days 00:48:43         9999
# 27-005-1703  Pcc27_005 0 days 00:48:42         9999
#
#                                    conllu_path  conllu_MB        conllu_mtime  \
# record
# 24-040-2011  Pcc24.conll/pcc_eng_24-040.conllu     397.72 2022-05-02 23:21:00
# 18-091-2816  Pcc18.conll/pcc_eng_18-091.conllu     379.33 2022-05-24 22:04:00
# 10-024-1558  Pcc10.conll/pcc_eng_10-024.conllu     391.74 2022-04-26 22:02:00
# 10-048-1630  Pcc10.conll/pcc_eng_10-048.conllu     389.63 2022-04-27 21:34:00
# 10-026-1573  Pcc10.conll/pcc_eng_10-026.conllu     384.32 2022-04-27 00:22:00
# ...                                        ...        ...                 ...
# 13-004-0098  Pcc13.conll/pcc_eng_13-004.conllu     378.65 2022-04-13 07:07:00
# 14-103-1600  Pcc14.conll/pcc_eng_14-103.conllu     390.02 2022-04-27 05:16:00
# 12-003-0079  Pcc12.conll/pcc_eng_12-003.conllu     371.03 2022-04-13 06:13:00
# 29-048-1752  Pcc29.conll/pcc_eng_29-048.conllu     384.12 2022-04-28 11:24:00
# 27-005-1703  Pcc27.conll/pcc_eng_27-005.conllu     396.62 2022-04-28 05:28:00
#
#                     finished_at
# record
# 24-040-2011 2022-05-02 23:21:00
# 18-091-2816 2022-05-24 22:04:00
# 10-024-1558 2022-04-26 22:02:00
# 10-048-1630 2022-04-27 21:34:00
# 10-026-1573 2022-04-27 00:22:00
# ...                         ...
# 13-004-0098 2022-04-13 07:07:00
# 14-103-1600 2022-04-27 05:16:00
# 12-003-0079 2022-04-13 06:13:00
# 29-048-1752 2022-04-28 11:25:00
# 27-005-1703 2022-04-28 05:28:00
#
# [216 rows x 7 columns]

# %%
slow.sort_values('seconds', ascending=False)[['slice_name', 'time', 'total_texts', 'conllu_path', 'conllu_MB', 'conllu_mtime', 'finished_at']].describe()
# Out:
#                             time   total_texts   conllu_MB
# count                        216    216.000000  216.000000
# mean   0 days 00:53:12.342592592  10008.402778  382.512407
# std    0 days 00:05:55.432462744     97.489032    7.984703
# min              0 days 00:48:42   9999.000000  364.480000
# 25%       0 days 00:50:05.500000   9999.000000  377.525000
# 50%       0 days 00:51:30.500000   9999.000000  381.245000
# 75%              0 days 00:53:47   9999.000000  386.012500
# max              0 days 01:30:27  11015.000000  425.390000

# %%
# for g, d in info.groupby('data_origin_group'): 
#     print('\n',g)
#     print(list(d.conllu_path.unique()))

# %%
info.loc[:, ['finished_at', 'total_texts', 'time']].sort_values('total_texts').head(10)
# Out:
#                     finished_at  total_texts            time
# record
# 29-108-1917 2022-04-30 03:57:00         6829 0 days 00:26:00
# 29-109-1919 2022-04-30 04:24:00         6830 0 days 00:27:27
# 08-107-2643 2022-05-04 19:58:00         9274 0 days 00:29:56
# 08-108-2650 2022-05-04 20:27:00         9274 0 days 00:29:22
# 11-107-1447 2022-04-22 11:28:00         9515 0 days 00:41:11
# 11-108-1457 2022-04-22 12:10:00         9515 0 days 00:42:19
# 25-107-1531 2022-04-22 20:15:00         9873 0 days 00:35:29
# 25-108-1534 2022-04-22 20:51:00         9873 0 days 00:35:38
# 18-107-2864 2022-05-25 07:59:00         9882 0 days 00:33:45
# 18-108-2867 2022-05-25 08:33:00         9883 0 days 00:33:41

# %%
info.loc[:, ['finished_at', 'total_texts', 'time']].sort_values('total_texts').tail(10)
# Out:
#                     finished_at  total_texts            time
# record
# 15-107-1458 2022-04-22 12:12:00        11062 0 days 00:43:59
# 15-108-1466 2022-04-22 12:57:00        11063 0 days 00:45:03
# 21-107-2539 2022-05-04 12:26:00        11149 0 days 00:38:17
# 21-108-2548 2022-05-04 13:05:00        11150 0 days 00:38:12
# 09-107-1490 2022-04-22 15:04:00        11306 0 days 00:44:08
# VA-002-3367 2022-06-22 14:35:00        11306 0 days 00:43:24
# 09-108-1499 2022-04-22 15:48:00        11307 0 days 00:44:23
# VA-003-3369 2022-06-22 15:17:00        11307 0 days 00:42:00
# TE-002-3366 2022-06-22 14:33:00        11349 0 days 00:40:53
# TE-003-3368 2022-06-22 15:14:00        11350 0 days 00:41:02

# %%
info.to_csv('/share/compling/data/puddin/completed-puddin_meta-index.csv')
