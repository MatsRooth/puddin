# %%
import pandas as pd
from pathlib import Path

# %%
dfpath = Path("pile_exclusions/pile_test-sample_Pile-CC_excl.pkl.gz").resolve()
df_exclude = pd.read_pickle(dfpath)
df_exclude.head()
# Out:
#                text_id                                               text  \
# 8   pcc_test-sample_09  {"whToggleConfig":{"cardsList":{}},"enableGeol...
# 35  pcc_test-sample_36  Detailed Description
#
# This is the interface fo...
# 15  pcc_test-sample_16  Data Use Policy
#
# 1. Information we receive and...
# 0   pcc_test-sample_01  Mud Hens pitcher Evan Reed charged with sexual...
# 2   pcc_test-sample_03  Mounting tensions with Syria sink US stocks
#
# N...
#
#    pile_set_name pile_set_code  \
# 8        Pile-CC           Pcc
# 35       Pile-CC           Pcc
# 15       Pile-CC           Pcc
# 0        Pile-CC           Pcc
# 2        Pile-CC           Pcc
#
#                                                   raw excl_type
# 8   {"whToggleConfig":{"cardsList":{}},"enableGeol...      html
# 35  Detailed Description
#
# This is the interface fo...      code
# 15  Data Use Policy
#
# 1. Information we receive and...      _wrd
# 0   Mud Hens pitcher Evan Reed charged with sexual...     a0wrd
# 2   Mounting tensions with Syria sink US stocks
#
# N...     a0wrd

# %%
dfp1 = Path("pile_tables/pile_test-sample_Pile-CC_df.pkl.gz").resolve()
df_include = pd.read_pickle(dfp1)
df_include.head()
# Out:
#               text_id pile_set_code pile_set_name  \
# 1  pcc_test-sample_02           Pcc       Pile-CC
# 4  pcc_test-sample_05           Pcc       Pile-CC
# 6  pcc_test-sample_07           Pcc       Pile-CC
# 7  pcc_test-sample_08           Pcc       Pile-CC
# 9  pcc_test-sample_10           Pcc       Pile-CC
#
#                                   data_origin_fpath  \
# 1  /home/arh234/litotes/pile_data/test-sample.jsonl
# 4  /home/arh234/litotes/pile_data/test-sample.jsonl
# 6  /home/arh234/litotes/pile_data/test-sample.jsonl
# 7  /home/arh234/litotes/pile_data/test-sample.jsonl
# 9  /home/arh234/litotes/pile_data/test-sample.jsonl
#
#                                      dataframe_fpath  \
# 1  /home/arh234/litotes/pile_tables/pile_test-sam...
# 4  /home/arh234/litotes/pile_tables/pile_test-sam...
# 6  /home/arh234/litotes/pile_tables/pile_test-sam...
# 7  /home/arh234/litotes/pile_tables/pile_test-sam...
# 9  /home/arh234/litotes/pile_tables/pile_test-sam...
#
#                                                 text
# 1  I'm getting about the same thing trying to upd...
# 4  Tag Archives: west texas
#
# Post navigation
#
# In ...
# 6  Hi all! It's been a long while since I posted ...
# 7  Straight waveguide can be manufactured with di...
# 9  The FAM Newsletter
#
# You know those letters you...

# %%
df_include.columns
# Out:
# Index(['text_id', 'pile_set_code', 'pile_set_name', 'data_origin_fpath',
#        'dataframe_fpath', 'text'],
#       dtype='object')
